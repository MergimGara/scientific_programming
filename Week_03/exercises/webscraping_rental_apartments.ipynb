# %% [markdown]
# # Web Scraping Rental Apartment Data with Python and Beautifulsoup
#
# Data from: https://www.immoscout24.ch/de/immobilien/mieten/ort-zuerich?pn=1

# %% [markdown]
# ## Libraries and settings

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# %% [markdown]
# ## Example of scraping data from a website with BeautifulSoup

# %%
# Send a GET request to the input URL
response = requests.get('https://www.immoscout24.ch/de/immobilien/mieten/ort-zuerich?pn=1')

# Parse the content of the request with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Extract the listings from the parsed content
# 'div' is the HTML tag (division) of the element that contains the listings
# 'class_' is the CSS class of the element that contains the listings
listings = soup.find_all('div', class_='HgListingRoomsLivingSpacePrice_roomsLivingSpacePrice_M6Ktp')

# Show first 10 listings
listings[0:10]
# Out:
# [<div class="HgListingRoomsLivingSpacePrice_roomsLivingSpacePrice_M6Ktp"><strong>6.5 Zimmer</strong><span>, </span><strong title="Wohnfläche">150m²</strong><span class="HgListingRoomsLivingSpacePrice_commaPrice_mXXpt">,</span><span class="HgListingRoomsLivingSpacePrice_price_u9Vee"> CHF 6’270.– <!-- --><!-- --></span></div>,
#  <div class="HgListingRoomsLivingSpacePrice_roomsLivingSpacePrice_M6Ktp"><strong>6.5 Zimmer</strong><span>, </span><strong title="Wohnfläche">160m²</strong><span class="HgListingRoomsLivingSpacePrice_commaPrice_mXXpt">,</span><span class="HgListingRoomsLivingSpacePrice_price_u9Vee"> CHF 6’470.– <!-- --><!-- --></span></div>,
#  <div class="HgListingRoomsLivingSpacePrice_roomsLivingSpacePrice_M6Ktp"><strong>5.5 Zimmer</strong><span>, </span><strong title="Wohnfläche">140m²</strong><span class="HgListingRoomsLivingSpacePrice_commaPrice_mXXpt">,</span><span class="HgListingRoomsLivingSpacePrice_price_u9Vee"> CHF 5’170.– <!-- --><!-- --></span></div>,
#  <div class="HgListingRoomsLivingSpacePrice_roomsLivingSpacePrice_M6Ktp"><strong>5.5 Zimmer</strong><span>, </span><strong title="Wohnfläche">128m²</strong><span class="HgListingRoomsLivingSpacePrice_commaPrice_mXXpt">,</span><span class="HgListingRoomsLivingSpacePrice_price_u9Vee"> CHF 4’940.– <!-- --><!-- --></span></div>,
#  <div class="HgListingRoomsLivingSpacePrice_roomsLivingSpacePrice_M6Ktp"><strong>5.5 Zimmer</strong><span>, </span><strong title="Wohnfläche">127m²</strong><span class="HgListingRoomsLivingSpacePrice_commaPrice_mXXpt">,</span><span class="HgListingRoomsLivingSpacePrice_price_u9Vee"> CHF 4’840.– <!-- --><!-- --></span></div>,
#  <div class="HgListingRoomsLivingSpacePrice_roomsLivingSpacePrice_M6Ktp"><strong>4.5 Zimmer</strong><span>, </span><strong title="Wohnfläche">107m²</strong><span class="HgListingRoomsLivingSpacePrice_commaPrice_mXXpt">,</span><span class="HgListingRoomsLivingSpacePrice_price_u9Vee"> CHF 4’450.– <!-- --><!-- --></span></div>,
#  <div class="HgListingRoomsLivingSpacePrice_roomsLivingSpacePrice_M6Ktp"><strong>5.5 Zimmer</strong><span>, </span><strong title="Wohnfläche">127m²</strong><span class="HgListingRoomsLivingSpacePrice_commaPrice_mXXpt">,</span><span class="HgListingRoomsLivingSpacePrice_price_u9Vee"> CHF 5’120.– <!-- --><!-- --></span></div>,
#  <div class="HgListingRoomsLivingSpacePrice_roomsLivingSpacePrice_M6Ktp"><strong>4.5 Zimmer</strong><span>, </span><strong title="Wohnfläche">86m²</strong><span class="HgListingRoomsLivingSpacePrice_commaPrice_mXXpt">,</span><span class="HgListingRoomsLivingSpacePrice_price_u9Vee"> CHF 3’570.– <!-- --><!-- --></span></div>,
#  <div class="HgListingRoomsLivingSpacePrice_roomsLivingSpacePrice_M6Ktp"><strong>2.5 Zimmer</strong><span>, </span><strong title="Wohnfläche">39m²</strong><span class="HgListingRoomsLivingSpacePrice_commaPrice_mXXpt">,</span><span class="HgListingRoomsLivingSpacePrice_price_u9Vee"> CHF 730.– <!-- --><!-- --></span></div>,
#  <div class="HgListingRoomsLivingSpacePrice_roomsLivingSpacePrice_M6Ktp"><strong>4.5 Zimmer</strong><span>, </span><strong title="Wohnfläche">94m²</strong><span class="HgListingRoomsLivingSpacePrice_commaPrice_mXXpt">,</span><span class="HgListingRoomsLivingSpacePrice_price_u9Vee"> CHF 4’300.– <!-- --><!-- --></span></div>]

# %% [markdown]
# ## Web Scraper function

# %%
# Function to extract the listings from a given URL
def extract_listing_info(url):

    # Send a GET request to the input URL
    response = requests.get(url)

    # Parse the content of the request with BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the listings from the parsed content
    listings = soup.find_all('div', class_='HgListingCard_info_RKrwz')
    
    # Initialize an empty list to store the extracted data
    extracted_data = []
    
    # Loop through the listings and extract the required information
    for listing in listings:
        # Extract address
        address_tag = listing.find('address')
        address = address_tag.text.strip() if address_tag else 'N/A'

        # Extract rooms, living area, and price
        info_section = listing.find('div', class_='HgListingRoomsLivingSpacePrice_roomsLivingSpacePrice_M6Ktp')
        if info_section:
            info_text = [strong.text.strip() for strong in info_section.find_all('strong')]
            rooms = info_text[0] if len(info_text) > 0 else 'N/A'
            living_area = info_text[1] if len(info_text) > 1 else 'N/A'
            price_tag = info_section.find('span', class_='HgListingRoomsLivingSpacePrice_price_u9Vee')
            price = price_tag.text.strip() if price_tag else 'N/A'
        else:
            rooms, living_area, price = 'N/A', 'N/A', 'N/A'

        # Extract title and description
        title_tag = listing.find('p', class_='HgListingDescription_title_NAAxy')
        title = title_tag.text.strip() if title_tag else 'N/A'

        description_tag = listing.find('p', class_='HgListingDescription_large_uKs3J')
        description = description_tag.text.strip() if description_tag else 'N/A'

        # Append extracted data to the list
        extracted_data.append({
            'address_raw': address,
            'rooms_raw': rooms,
            'area_raw': living_area,
            'price_raw': price,
            'title_raw': title,
            'description_raw': description
        })
    
    # Return the extracted data
    return extracted_data

# %% [markdown]
# ## Call the Web Scraper function to get apartment data from the 1st page

# %%
# Scrape 1st page
url = 'https://www.immoscout24.ch/de/immobilien/mieten/ort-zuerich?pn=1'

# Extract listing information to a list object 'data'
data = extract_listing_info(url)

# Create DataFrame from 'data'
df = pd.DataFrame(data)

# Show the first few rows of the DataFrame
df.head()
# Out:
#                          address_raw   rooms_raw area_raw    price_raw  \
# 0    Weidmannstrasse 13, 8046 Zürich  6.5 Zimmer    150m²  CHF 6’270.–
# 1      Segnesstrasse 12, 8048 Zürich  6.5 Zimmer    160m²  CHF 6’470.–
# 2       Segnesstrasse 8, 8048 Zürich  5.5 Zimmer    140m²  CHF 5’170.–
# 3  Anna-Heer-Strasse 12, 8057 Zürich  5.5 Zimmer    128m²  CHF 4’940.–
# 4  Anna-Heer-Strasse 16, 8057 Zürich  5.5 Zimmer    127m²  CHF 4’840.–
#
#                                            title_raw  \
# 0  Luxuriöse 6.5-Zimmerwohnung mit großzügigem Ga...
# 1          Exklusive Erstvermietung - Projekt "TILIA
# 2         Exklusive Erstvermietung - Projekt "TILIA"
# 3                        5.5 Zimmerwohnung in Zürich
# 4                        5.5 Zimmerwohnung in Zürich
#
#                                      description_raw
# 0  Moderne und wunderschöne 6.5-Zimmerwohnung mit...
# 1  Im Projekt «TILIA» finden Sie 72 stilvolle 1.5...
# 2  Im Projekt «TILIA» finden Sie 72 stilvolle 1.5...
# 3  An der Anna-Heer-Strasse in Zürich entstehen m...
# 4  An der Anna-Heer-Strasse in Zürich entstehen m...

# %% [markdown]
# ## Call the Web Scraper function to get apartment data from multiple pages

# %%
# Scrape multiple pages
data = []
base_url = 'https://www.immoscout24.ch/de/immobilien/mieten/ort-zuerich?pn='

for page in range(1, 4):  # pages 1 to 3
    url = base_url + str(page)
    print(f"Scraping {url}...")
    data.extend(extract_listing_info(url))

# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv('./data/rental_apartments_zuerich.csv', index=False)

print("\nData saved to real_estate_listings.csv")

# Show the first few rows of the DataFrame
df.head()
# Out:
# Scraping https://www.immoscout24.ch/de/immobilien/mieten/ort-zuerich?pn=1...
# Scraping https://www.immoscout24.ch/de/immobilien/mieten/ort-zuerich?pn=2...
# Scraping https://www.immoscout24.ch/de/immobilien/mieten/ort-zuerich?pn=3...
#
# Data saved to real_estate_listings.csv
#                          address_raw   rooms_raw area_raw    price_raw  \
# 0    Weidmannstrasse 13, 8046 Zürich  6.5 Zimmer    150m²  CHF 6’270.–
# 1      Segnesstrasse 12, 8048 Zürich  6.5 Zimmer    160m²  CHF 6’470.–
# 2       Segnesstrasse 8, 8048 Zürich  5.5 Zimmer    140m²  CHF 5’170.–
# 3  Anna-Heer-Strasse 12, 8057 Zürich  5.5 Zimmer    128m²  CHF 4’940.–
# 4  Anna-Heer-Strasse 16, 8057 Zürich  5.5 Zimmer    127m²  CHF 4’840.–
#
#                                            title_raw  \
# 0  Luxuriöse 6.5-Zimmerwohnung mit großzügigem Ga...
# 1          Exklusive Erstvermietung - Projekt "TILIA
# 2         Exklusive Erstvermietung - Projekt "TILIA"
# 3                        5.5 Zimmerwohnung in Zürich
# 4                        5.5 Zimmerwohnung in Zürich
#
#                                      description_raw
# 0  Moderne und wunderschöne 6.5-Zimmerwohnung mit...
# 1  Im Projekt «TILIA» finden Sie 72 stilvolle 1.5...
# 2  Im Projekt «TILIA» finden Sie 72 stilvolle 1.5...
# 3  An der Anna-Heer-Strasse in Zürich entstehen m...
# 4  An der Anna-Heer-Strasse in Zürich entstehen m...

# %% [markdown]
# ## Extract prices from strings using a regular expression (regex)

# %%
# Extract prices from the 'price_raw' column using a regular expression (regex)
df['price'] = df['price_raw'].str.extract(r'(\d[\d’]*\d)')

# Remove thousands separator and convert to integer
df['price'] = df['price'].str.replace('’', '').astype(float)

# Show the first few rows of the DataFrame (selected columns)
df[['address_raw', 'rooms_raw', 'area_raw', 'price_raw', 'price']].head()
# Out:
#                          address_raw   rooms_raw area_raw    price_raw   price
# 0    Weidmannstrasse 13, 8046 Zürich  6.5 Zimmer    150m²  CHF 6’270.–  6270.0
# 1      Segnesstrasse 12, 8048 Zürich  6.5 Zimmer    160m²  CHF 6’470.–  6470.0
# 2       Segnesstrasse 8, 8048 Zürich  5.5 Zimmer    140m²  CHF 5’170.–  5170.0
# 3  Anna-Heer-Strasse 12, 8057 Zürich  5.5 Zimmer    128m²  CHF 4’940.–  4940.0
# 4  Anna-Heer-Strasse 16, 8057 Zürich  5.5 Zimmer    127m²  CHF 4’840.–  4840.0

# %% [markdown]
# ## Create histogram of prices

# %%
# Plot a histogram of the prices
plt.figure(figsize=(7, 4))
plt.hist(df['price'], bins=30, color='greenyellow', edgecolor='gray')
plt.title('Histogram of prices')
plt.xlabel('Price (CHF)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2025-03-05 11:45:10
# Python Version: 3.11.11
# -----------------------------------
